# %% [markdown]
# <a href="https://colab.research.google.com/github/yybbyyya-329/ABCD-A/blob/20250307/%ED%8C%8C%EC%9D%B4%EC%8D%AC_%EA%B8%B0%EC%B4%88_20250309.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
watch=100000
a='pig'
b='dad'

print(a)
print(b)
print(watch)
print(a+b)
print(a+' '+b)

aa=1
bb=100
aa,bb=bb,aa
print(aa)
print(bb)

a1=[10,20,30]
b1=a1
a1[0]
print(b1)

print("Hello world")
print('Hello world')
print(1)
print("1")

c=1
print("c="+str(c))
print("c=",c)
print("c={}",format(c))

#day1
a={10,20,30}
b=1
c=2
print(a)
print("a={}",format(a))
print("b={}",format(b))
print("a={},b={},c={}".format(a,b,c))
# Out:
# pig
# dad
# 100000
# pigdad
# pig dad
# 100
# 1
# [10, 20, 30]
# Hello world
# Hello world
# 1
# 1
# c=1
# c= 1
# c={} 1
# {10, 20, 30}
# a={} {10, 20, 30}
# b={} 1
# a={10, 20, 30},b=1,c=2

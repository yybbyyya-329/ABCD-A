# %% [markdown]
# <a href="https://colab.research.google.com/github/yybbyyya-329/ABCD-A/blob/20250307/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 print ("test")
# Out:
# test

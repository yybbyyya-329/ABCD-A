# %% [markdown]
# <a href="https://colab.research.google.com/github/yybbyyya-329/ABCD-A/blob/20250307/%ED%8C%8C%EC%9D%B4%EC%8D%AC300%EC%A0%9C_1_10_%EB%AC%B8%EC%A0%9C%ED%92%80%EC%9D%B4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 화면에 Hello world 문자열을 출력하세요.
print("Hello world")
# Out:
# Hello world
# Mary's cosmetics

# %%
# 화면에 Mary's cosmetics을 출력하세요. (중간에 '가 있음에 주의하세요.)
print("Mary's cosmetics")
# Out:
# Mary's cosmetics

# %%
# 화면에 아래 문장을 출력하세요. (중간에 "가 있음에 주의하세요.)
print('신씨가 소리를 질렀다."도둑이야."')
# Out:
# 신씨가 소리를 질렀다."도둑이야"

# %%
# 화면에 "C:\\windows"를 출력하세요.
print("c:\\windows")
# Out:
# c:\windows

# %%
# 다음 코드를 실행보고 \t와 \n의 역할을 설명해보세요.
print("안녕하세요.\n만나서\t\t\반갑습니다.")
# Out:
# 안녕하세요.
# 만나서		\반갑습니다.

# %%
# print 함수에 두 개의 단어를 입력한 예제입니다. 아래 코드의 출력 결과를 예상해봅시다.
print("오늘은", "일요일")
# Out:
# 오늘은 일요일

# %%
# print() 함수를 사용하여 다음과 같이 출력하세요.
print("naver;kakao;sk;samsung")
print("naver", "kakao", "sk", "samsung", end=';')
print("naver", "kakao", "sk", "samsung", sep=';')
# Out:
# naver;kakao;sk;samsung
# naver kakao sk samsung;naver;kakao;sk;samsung

# %%
# print() 함수를 사용하여 다음과 같이 출력하세요.
print("naver", "kakao", "sk", "samsung", sep='/')
# Out:
# naver/kakao/sk/samsung

# %%
# 다음 코드를 수정하여 줄바꿈 없이 출력하세요. (힌트:end=") print 함수는 두 번 사용합니다. 세미콜론(;)은 한 줄에 여러 개의 명령을 작성하기 위해 사용합니다.
print("first");print("second")
print("first", end="");print("second")
print("first", end="")
print("second", end="")
print("third")
# Out:
# first
# second
# firstsecond
# firstsecondthird

# %%
# 5/3의 결과를 화면에 출력하세요.
print(5/3)
# Out:
# 1.6666666666666667

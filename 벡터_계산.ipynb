# %% [markdown]
# <a href="https://colab.research.google.com/github/yybbyyya-329/ABCD-A/blob/20250331/%EB%B2%A1%ED%84%B0_%EA%B3%84%EC%82%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#첫 번째 벡터 입력 받기
x1 = float(input("첫 번째 벡터의 x성분을 입력하세요"))
y1 = float(input("첫 번째 벡터의 y 성분을 입력하세요: "))
# Out:
# 첫 번째 벡터의 x성분을 입력하세요3
# 첫 번째 벡터의 y 성분을 입력하세요: 6

# %%
# 두 번째 벡터 입력 받기

x2 = float(input("두 번째 벡터의 x 성분을 입력하세요: "))

y2 = float(input("두 번째 벡터의 y 성분을 입력하세요: "))
# Out:
# 두 번째 벡터의 x 성분을 입력하세요: 5
# 두 번째 벡터의 y 성분을 입력하세요: 9

# %%
# 벡터의 합 계산

sum_x = x1 + x2

sum_y = y1 + y2

# %%
# 벡터의 내적 계산 (dot product)

dot_product = x1 * x2 + y1 * y2

# %%
# 벡터의 외적 계산 (cross product)

# 2차원 벡터의 외적은 스칼라 값으로, z축 방향의 크기를 나타냅니다

cross_product = x1 * x2 - y1 * y2

# %%
# 결과 출력

print("\n벡터 1:", x1, "i +", y1, "j")

print("벡터 2:", x2, "i +", y2, "j")

print("\n벡터의 합:", sum_x, "i +", sum_y, "j")

print("벡터의 내적:", dot_product)

print("벡터의 외적:", cross_product)
# Out:
# 벡터 1: 3.0 i + 6.0 j
# 벡터 2: 5.0 i + 9.0 j
#
# 벡터의 합: 8.0 i + 15.0 j
# 벡터의 내적: 69.0
# 벡터의 외적: -39.0

# %%
z1 = float(input("첫 번째 벡터의 z 성분을 입력하세요: "))
z2 = float(input("첫 번째 벡터의 z 성분을 입력하세요: "))
sum_z = z1 + z2

dot_produt_3d = x1 * x2 + y1 * y2 + z1 * z2

cross_x = y1 * z2 - z1 * y2
cross_y = z1 * x2 - x1 * z2
cross_z = x1 * y2 - y1 * x2
cross_product_3d = [cross_x, cross_y, cross_z]
# Out:
# 첫 번째 벡터의 z 성분을 입력하세요: 2
# 첫 번째 벡터의 z 성분을 입력하세요: 8

# %%
print("\n벡터 1:", x1, "i +", y1, "j", z1,"k")
print("벡터 2:", x2, "i +", y2, "j", z2, "k")
print("\n벡터의 합:", sum_x, "i +", sum_y, "j", sum_z, "k")
print("벡터의 내적:", dot_produt_3d)
print("벡터의 외적:", cross_product_3d)
# Out:
# 벡터 1: 3.0 i + 6.0 j 2.0 k
# 벡터 2: 5.0 i + 9.0 j 8.0 k
#
# 벡터의 합: 8.0 i + 15.0 j 10.0 k
# 벡터의 내적: 85.0
# 벡터의 외적: [30.0, -14.0, -3.0]
